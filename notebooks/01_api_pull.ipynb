# %%
from src.api_utils import get_census_data

API_KEY = "cc5c34cba57b140d13e211510250a3beee882af6"

# Example: Rare-earth metals (280530) from Canada (1220), full year 2024
df = get_census_data(country_code="1220", hs_code="280530", time="2024-12", api_key=API_KEY)

print(df)
